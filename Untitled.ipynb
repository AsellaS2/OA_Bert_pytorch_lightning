# %%
import pandas as pd
import numpy as np

from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup

import torch
from torch import nn, cuda
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler, TensorDataset

import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint

from sklearn import metrics
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

from bert_op import *


RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
inputpath = 'D:/project/OA_paper/DATA/Combine/'
savepath = ''

df = pd.read_csv(inputpath + 'labeling_merge.csv', encoding='cp949')

x = list(df['rejectionContentDetail'])
y = list(map(lambda x: x.split(', '), df['label']))

# %%
x = x[:1000]
y = y[:1000]

# %%
y
# Out:
# [['외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['외관유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['기타'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['관념유사', '외관유사', '상품 불명확'],
#  ['관념유사', '식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['기타'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['기타'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력', '상품 불명확'],
#  ['발음유사', '기타'],
#  ['발음유사', '식별력'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '식별력'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사'],
#  ['관념유사'],
#  ['관념유사'],
#  ['발음유사', '관념유사'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사'],
#  ['관념유사'],
#  ['관념유사'],
#  ['발음유사', '관념유사'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['관념유사'],
#  ['관념유사'],
#  ['관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['외관유사'],
#  ['외관유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['기타'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '식별력'],
#  ['외관유사', '식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['외관유사'],
#  ['외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '기타'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['기타'],
#  ['발음유사', '식별력'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['기타'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['외관유사', '상품 불명확'],
#  ['외관유사', '기타'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사', '식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['관념유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['기타'],
#  ['발음유사', '관념유사', '외관유사', '식별력', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['기타'],
#  ['기타'],
#  ['발음유사', '기타'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '외관유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['관념유사', '외관유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['외관유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '식별력'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['외관유사'],
#  ['외관유사'],
#  ['관념유사', '상품 불명확'],
#  ['외관유사', '기타'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['기타'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확']]

# %%
mlb = MultiLabelBinarizer()
yt = mlb.fit_transform(y)
print(mlb.classes_)
# Out:
# ['관념유사' '기타' '발음유사' '상품 불명확' '식별력' '외관유사']

# %%
# Next split Train in to training and validation
x_tr, x_val, y_tr, y_val = train_test_split(x, y, test_size=0.2, random_state=RANDOM_SEED, shuffle=True)

# %%
y_tr
# Out:
# [['기타'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['기타'],
#  ['외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '식별력'],
#  ['관념유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['외관유사'],
#  ['외관유사'],
#  ['관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['기타'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['기타'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '기타'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['외관유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사', '식별력'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['발음유사', '식별력'],
#  ['상품 불명확'],
#  ['외관유사', '기타'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['기타'],
#  ['관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['외관유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['기타'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '식별력'],
#  ['관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['외관유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '기타'],
#  ['발음유사'],
#  ['관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['외관유사'],
#  ['상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['기타'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['외관유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['관념유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '외관유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '식별력'],
#  ['상품 불명확'],
#  ['발음유사', '외관유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['식별력'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사', '식별력'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['외관유사', '기타'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['관념유사', '식별력'],
#  ['발음유사'],
#  ['외관유사', '식별력'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['식별력'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력', '상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '상품 불명확'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['외관유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사', '관념유사'],
#  ['식별력'],
#  ['상품 불명확'],
#  ['식별력', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사', '식별력', '상품 불명확'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['식별력', '상품 불명확'],
#  ['발음유사'],
#  ['관념유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '외관유사', '상품 불명확'],
#  ['관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['발음유사', '상품 불명확'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사', '관념유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '식별력'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['상품 불명확'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['식별력', '상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사'],
#  ['발음유사', '상품 불명확'],
#  ['상품 불명확'],
#  ['상품 불명확'],
#  ['발음유사', '관념유사', '외관유사'],
#  ['발음유사'],
#  ['식별력'],
#  ['발음유사'],
#  ['발음유사'],
#  ['발음유사', '관념유사'],
#  ['발음유사'],
#  ['발음유사']]

# %%
# Initialize the Bert tokenizer
BERT_MODEL_NAME = "bert-base-multilingual-cased"
Bert_tokenizer = BertTokenizer.from_pretrained(BERT_MODEL_NAME)

max_word_cnt = 512
content_cnt = 0

contents = x

# For every sentence...
for content in contents:

    # Tokenize the text and add `[CLS]` and `[SEP]` tokens.
    input_ids = Bert_tokenizer.encode(content, add_special_tokens=True)

    # Update the maximum sentence length.
    if len(input_ids) > max_word_cnt:
        content_cnt += 1
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (601 > 512). Running this sequence through the model will result in indexing errors

# %%
# Initialize the parameters that will be use for training
N_EPOCHS = 3
BATCH_SIZE = 8
MAX_LEN = 512
LR = 2e-05

# %%
# Instantiate and set up the data_module
OAdata_module = TrainOADataModule(x_tr=x_tr, y_tr=y_tr, x_val=x_val, y_val=y_val, tokenizer=Bert_tokenizer,
                                   batch_size=BATCH_SIZE, max_token_len=MAX_LEN)
OAdata_module.setup()

# %%
# Instantiate the classifier model
steps_per_epoch = len(x_tr)//BATCH_SIZE
model = OAClassifier(n_classes=6, steps_per_epoch=steps_per_epoch,n_epochs=N_EPOCHS,lr=LR)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# saves a file like: input/OA-epoch=02-val_loss=0.32.ckpt
checkpoint_callback = ModelCheckpoint(
    monitor='val_loss',                         # monitored quantity
    filename='OA-{epoch:02d}-{val_loss:.2f}',
    save_top_k=3,                               # save the top 3 models
    mode='min',                                 # mode of the monitored quantity for optimization
)

# %%
# Instantiate the Model Trainer
trainer = pl.Trainer(max_epochs=N_EPOCHS, gpus=1, callbacks=[checkpoint_callback], progress_bar_refresh_rate=30)

# Train the Classifier Model
trainer.fit(model, OAdata_module)

# Evaluate the model performance on the test dataset
trainer.test(model, datamodule=OAdata_module)

# Retreive the checkpoint path for best model
model_path = checkpoint_callback.best_model_path
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type              | Params
# -------------------------------------------------
# 0 | bert       | BertModel         | 177 M
# 1 | classifier | Linear            | 4.6 K
# 2 | criterion  | BCEWithLogitsLoss | 0
# -------------------------------------------------
# 177 M     Trainable params
# 0         Non-trainable params
# 177 M     Total params
# 711.432   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\utilities\distributed.py:69: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0eccfeb2feba> in <module>
#       3
#       4 # Train the Classifier Model
# ----> 5 trainer.fit(model, OAdata_module)
#       6
#       7 # Evaluate the model performance on the test dataset
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     456         )
#     457
# --> 458         self._run(model)
#     459
#     460         assert self.state.stopped
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in _run(self, model)
#     754
#     755         # dispatch `start_training` or `start_evaluating` or `start_predicting`
# --> 756         self.dispatch()
#     757
#     758         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in dispatch(self)
#     795             self.accelerator.start_predicting(self)
#     796         else:
# --> 797             self.accelerator.start_training(self)
#     798
#     799     def run_stage(self):
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\accelerators\accelerator.py in start_training(self, trainer)
#      94
#      95     def start_training(self, trainer: 'pl.Trainer') -> None:
# ---> 96         self.training_type_plugin.start_training(trainer)
#      97
#      98     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\plugins\training_type\training_type_plugin.py in start_training(self, trainer)
#     142     def start_training(self, trainer: 'pl.Trainer') -> None:
#     143         # double dispatch to initiate the training loop
# --> 144         self._results = trainer.run_stage()
#     145
#     146     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in run_stage(self)
#     805         if self.predicting:
#     806             return self.run_predict()
# --> 807         return self.run_train()
#     808
#     809     def _pre_training_routine(self):
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in run_train(self)
#     840             self.progress_bar_callback.disable()
#     841
# --> 842         self.run_sanity_check(self.lightning_module)
#     843
#     844         self.checkpoint_connector.has_trained = False
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in run_sanity_check(self, ref_model)
#    1105
#    1106             # run eval step
# -> 1107             self.run_evaluation()
#    1108
#    1109             self.on_sanity_check_end()
#
# d:\project\oa_paper\venv\lib\site-packages\pytorch_lightning\trainer\trainer.py in run_evaluation(self, on_epoch)
#     947             dl_max_batches = self.evaluation_loop.max_batches[dataloader_idx]
#     948
# --> 949             for batch_idx, batch in enumerate(dataloader):
#     950                 if batch is None:
#     951                     continue
#
# d:\project\oa_paper\venv\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# d:\project\oa_paper\venv\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# d:\project\oa_paper\venv\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# d:\project\oa_paper\venv\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\project\OA_paper\bert_op.py in __getitem__(self, item_idx)
#      40             'input_ids': input_ids,
#      41             'attention_mask': attn_mask,
# ---> 42             'label': torch.tensor(self.labels[item_idx], dtype=torch.float)
#      43         }
#      44
#
# ValueError: too many dimensions 'str'
